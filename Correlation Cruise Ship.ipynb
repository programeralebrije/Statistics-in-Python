# %% [markdown]
# # Correlation

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cruise_ship = pd.read_excel(r'/Users/rubenlarrazolo/Downloads/cruise_ship.xlsx')
print(cruise_ship)
# Out:
#             Ship      Line  YearBlt  Tonnage  passngrs  Length  Cabins  Crew  \
# 0        Journey   Azamara     2007    30277       694     594     355   355
# 1          Quest   Azamara     2007    30277       694     594     355   355
# 2    Celebration  Carnival     1987    47262      1486     722     743   670
# 3       Conquest  Carnival     2002   110000      2974     953    1488  1910
# 4        Destiny  Carnival     1996   101353      2642     892    1321  1000
# ..           ...       ...      ...      ...       ...     ...     ...   ...
# 153       Taurus      Star     1991     3341        66     279      33    59
# 154        Virgo      Star     1999    76800      1960     879     967  1200
# 155       Spirit  Windstar     1988     5350       158     440      74    88
# 156         Star  Windstar     1986     5350       167     440      74    88
# 157         Surf  Windstar     1990    14745       308     617     156   180
#
#      PassSpcR  outcab
# 0       42.64     329
# 1       42.64     329
# 2       31.80     453
# 3       36.99     892
# 4       38.36     740
# ..        ...     ...
# 153     50.62      33
# 154     39.18     608
# 155     33.86      74
# 156     32.04      74
# 157     47.87     156
#
# [158 rows x 10 columns]

# %%
cruise_ship.head()
# Out:
#           Ship      Line  YearBlt  Tonnage  passngrs  Length  Cabins  Crew  \
# 0      Journey   Azamara     2007    30277       694     594     355   355
# 1        Quest   Azamara     2007    30277       694     594     355   355
# 2  Celebration  Carnival     1987    47262      1486     722     743   670
# 3     Conquest  Carnival     2002   110000      2974     953    1488  1910
# 4      Destiny  Carnival     1996   101353      2642     892    1321  1000
#
#    PassSpcR  outcab
# 0     42.64     329
# 1     42.64     329
# 2     31.80     453
# 3     36.99     892
# 4     38.36     740

# %%
cruise_ship['passngrs'].corr(cruise_ship['Cabins'])
# Out:
# 0.9763413679845939

# %%
cruise_ship1 = cruise_ship.drop(['Ship', 'Line'], axis=1)

# %%
cruise_ship.head()
# Out:
#           Ship      Line  YearBlt  Tonnage  passngrs  Length  Cabins  Crew  \
# 0      Journey   Azamara     2007    30277       694     594     355   355
# 1        Quest   Azamara     2007    30277       694     594     355   355
# 2  Celebration  Carnival     1987    47262      1486     722     743   670
# 3     Conquest  Carnival     2002   110000      2974     953    1488  1910
# 4      Destiny  Carnival     1996   101353      2642     892    1321  1000
#
#    PassSpcR  outcab
# 0     42.64     329
# 1     42.64     329
# 2     31.80     453
# 3     36.99     892
# 4     38.36     740

# %%
cruise_ship1.corr(method='pearson')
# Out:
#            YearBlt   Tonnage  passngrs    Length    Cabins      Crew  \
# YearBlt   1.000000  0.606646  0.515542  0.532286  0.510019  0.530657
# Tonnage   0.606646  1.000000  0.945061  0.922368  0.948764  0.927569
# passngrs  0.515542  0.945061  1.000000  0.883535  0.976341  0.915234
# Length    0.532286  0.922368  0.883535  1.000000  0.889798  0.895857
# Cabins    0.510019  0.948764  0.976341  0.889798  1.000000  0.950823
# Crew      0.530657  0.927569  0.915234  0.895857  0.950823  1.000000
# PassSpcR  0.278830 -0.040846 -0.294867 -0.090488 -0.253181 -0.155509
# outcab    0.547203  0.921931  0.914551  0.901047  0.934136  0.900466
#
#           PassSpcR    outcab
# YearBlt   0.278830  0.547203
# Tonnage  -0.040846  0.921931
# passngrs -0.294867  0.914551
# Length   -0.090488  0.901047
# Cabins   -0.253181  0.934136
# Crew     -0.155509  0.900466
# PassSpcR  1.000000 -0.145602
# outcab   -0.145602  1.000000

# %%
cruise_ship1.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style  type="text/css" >
# #T_fdc01_row0_col0,#T_fdc01_row1_col1,#T_fdc01_row2_col2,#T_fdc01_row3_col3,#T_fdc01_row4_col4,#T_fdc01_row5_col5,#T_fdc01_row6_col6,#T_fdc01_row7_col7{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_fdc01_row0_col1{
#             background-color:  #d1dae9;
#             color:  #000000;
#         }#T_fdc01_row0_col2{
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }#T_fdc01_row0_col3,#T_fdc01_row0_col5{
#             background-color:  #afcafc;
#             color:  #000000;
#         }#T_fdc01_row0_col4{
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }#T_fdc01_row0_col6,#T_fdc01_row1_col6,#T_fdc01_row2_col6,#T_fdc01_row3_col6,#T_fdc01_row4_col6,#T_fdc01_row5_col6,#T_fdc01_row6_col2,#T_fdc01_row7_col6{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_fdc01_row0_col7{
#             background-color:  #b7cff9;
#             color:  #000000;
#         }#T_fdc01_row1_col0{
#             background-color:  #f4c5ad;
#             color:  #000000;
#         }#T_fdc01_row1_col2,#T_fdc01_row4_col7{
#             background-color:  #c73635;
#             color:  #f1f1f1;
#         }#T_fdc01_row1_col3,#T_fdc01_row1_col7,#T_fdc01_row7_col2{
#             background-color:  #cf453c;
#             color:  #f1f1f1;
#         }#T_fdc01_row1_col4{
#             background-color:  #c53334;
#             color:  #f1f1f1;
#         }#T_fdc01_row1_col5,#T_fdc01_row7_col1{
#             background-color:  #cc403a;
#             color:  #f1f1f1;
#         }#T_fdc01_row2_col0{
#             background-color:  #f5c4ac;
#             color:  #000000;
#         }#T_fdc01_row2_col1,#T_fdc01_row4_col1,#T_fdc01_row4_col5,#T_fdc01_row5_col4{
#             background-color:  #c32e31;
#             color:  #f1f1f1;
#         }#T_fdc01_row2_col3,#T_fdc01_row3_col7,#T_fdc01_row5_col3{
#             background-color:  #d44e41;
#             color:  #000000;
#         }#T_fdc01_row2_col4,#T_fdc01_row4_col2{
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }#T_fdc01_row2_col5,#T_fdc01_row2_col7,#T_fdc01_row5_col1{
#             background-color:  #cb3e38;
#             color:  #f1f1f1;
#         }#T_fdc01_row3_col0{
#             background-color:  #edd1c2;
#             color:  #000000;
#         }#T_fdc01_row3_col1,#T_fdc01_row5_col2{
#             background-color:  #cd423b;
#             color:  #f1f1f1;
#         }#T_fdc01_row3_col2{
#             background-color:  #d85646;
#             color:  #000000;
#         }#T_fdc01_row3_col4{
#             background-color:  #d65244;
#             color:  #000000;
#         }#T_fdc01_row3_col5{
#             background-color:  #d55042;
#             color:  #000000;
#         }#T_fdc01_row4_col0{
#             background-color:  #f2c9b4;
#             color:  #000000;
#         }#T_fdc01_row4_col3,#T_fdc01_row5_col7,#T_fdc01_row7_col3,#T_fdc01_row7_col5{
#             background-color:  #d24b40;
#             color:  #f1f1f1;
#         }#T_fdc01_row5_col0{
#             background-color:  #f1ccb8;
#             color:  #000000;
#         }#T_fdc01_row6_col0{
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }#T_fdc01_row6_col1{
#             background-color:  #7a9df8;
#             color:  #000000;
#         }#T_fdc01_row6_col3{
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }#T_fdc01_row6_col4{
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }#T_fdc01_row6_col5{
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }#T_fdc01_row6_col7{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_fdc01_row7_col0{
#             background-color:  #f2cab5;
#             color:  #000000;
#         }#T_fdc01_row7_col4{
#             background-color:  #c83836;
#             color:  #f1f1f1;
#         }</style><table id="T_fdc01_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >YearBlt</th>        <th class="col_heading level0 col1" >Tonnage</th>        <th class="col_heading level0 col2" >passngrs</th>        <th class="col_heading level0 col3" >Length</th>        <th class="col_heading level0 col4" >Cabins</th>        <th class="col_heading level0 col5" >Crew</th>        <th class="col_heading level0 col6" >PassSpcR</th>        <th class="col_heading level0 col7" >outcab</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fdc01_level0_row0" class="row_heading level0 row0" >YearBlt</th>
#                         <td id="T_fdc01_row0_col0" class="data row0 col0" >1.0</td>
#                         <td id="T_fdc01_row0_col1" class="data row0 col1" >0.61</td>
#                         <td id="T_fdc01_row0_col2" class="data row0 col2" >0.52</td>
#                         <td id="T_fdc01_row0_col3" class="data row0 col3" >0.53</td>
#                         <td id="T_fdc01_row0_col4" class="data row0 col4" >0.51</td>
#                         <td id="T_fdc01_row0_col5" class="data row0 col5" >0.53</td>
#                         <td id="T_fdc01_row0_col6" class="data row0 col6" >0.28</td>
#                         <td id="T_fdc01_row0_col7" class="data row0 col7" >0.55</td>
#             </tr>
#             <tr>
#                         <th id="T_fdc01_level0_row1" class="row_heading level0 row1" >Tonnage</th>
#                         <td id="T_fdc01_row1_col0" class="data row1 col0" >0.61</td>
#                         <td id="T_fdc01_row1_col1" class="data row1 col1" >1.0</td>
#                         <td id="T_fdc01_row1_col2" class="data row1 col2" >0.95</td>
#                         <td id="T_fdc01_row1_col3" class="data row1 col3" >0.92</td>
#                         <td id="T_fdc01_row1_col4" class="data row1 col4" >0.95</td>
#                         <td id="T_fdc01_row1_col5" class="data row1 col5" >0.93</td>
#                         <td id="T_fdc01_row1_col6" class="data row1 col6" >-0.041</td>
#                         <td id="T_fdc01_row1_col7" class="data row1 col7" >0.92</td>
#             </tr>
#             <tr>
#                         <th id="T_fdc01_level0_row2" class="row_heading level0 row2" >passngrs</th>
#                         <td id="T_fdc01_row2_col0" class="data row2 col0" >0.52</td>
#                         <td id="T_fdc01_row2_col1" class="data row2 col1" >0.95</td>
#                         <td id="T_fdc01_row2_col2" class="data row2 col2" >1.0</td>
#                         <td id="T_fdc01_row2_col3" class="data row2 col3" >0.88</td>
#                         <td id="T_fdc01_row2_col4" class="data row2 col4" >0.98</td>
#                         <td id="T_fdc01_row2_col5" class="data row2 col5" >0.92</td>
#                         <td id="T_fdc01_row2_col6" class="data row2 col6" >-0.29</td>
#                         <td id="T_fdc01_row2_col7" class="data row2 col7" >0.91</td>
#             </tr>
#             <tr>
#                         <th id="T_fdc01_level0_row3" class="row_heading level0 row3" >Length</th>
#                         <td id="T_fdc01_row3_col0" class="data row3 col0" >0.53</td>
#                         <td id="T_fdc01_row3_col1" class="data row3 col1" >0.92</td>
#                         <td id="T_fdc01_row3_col2" class="data row3 col2" >0.88</td>
#                         <td id="T_fdc01_row3_col3" class="data row3 col3" >1.0</td>
#                         <td id="T_fdc01_row3_col4" class="data row3 col4" >0.89</td>
#                         <td id="T_fdc01_row3_col5" class="data row3 col5" >0.9</td>
#                         <td id="T_fdc01_row3_col6" class="data row3 col6" >-0.09</td>
#                         <td id="T_fdc01_row3_col7" class="data row3 col7" >0.9</td>
#             </tr>
#             <tr>
#                         <th id="T_fdc01_level0_row4" class="row_heading level0 row4" >Cabins</th>
#                         <td id="T_fdc01_row4_col0" class="data row4 col0" >0.51</td>
#                         <td id="T_fdc01_row4_col1" class="data row4 col1" >0.95</td>
#                         <td id="T_fdc01_row4_co

# %%
sns.heatmap(cruise_ship1.corr(), annot=True)
# Out:
# <AxesSubplot:>
